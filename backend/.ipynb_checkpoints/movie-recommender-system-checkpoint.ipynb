# %%
import numpy as np
import pandas as pd
import ast

# %%
movies_raw = pd.read_csv('dataset/movies.csv')
credits_raw = pd.read_csv('dataset/credits.csv')
ratings = pd.read_csv('dataset/ratings.csv')

# %%
movies = movies_raw.merge(credits_raw,on='title')

# %%
# movies.dropna()

# %%
# movies = pd.read_csv('movies_new.csv')

# %%
# movies.dropna()
# movies = movies.sort_values(by = 'vote_count',ascending=False)

# %%
# movies = movies.head(1500)

# %%
movies.head(20)
# Out:
#     movieId  tmdbId     budget  \
# 0         1      97  160000000
# 1         2      66  185000000
# 2         3       1  237000000
# 3         4      17  220000000
# 4         5     789   58000000
# 5         6      96  165000000
# 6         7     288  100000000
# 7         8      95  170000000
# 8         9     427   75000000
# 9        10     128  150000000
# 10       11     663   63000000
# 11       12       4  250000000
# 12       13     635   63000000
# 13       14      32  200000000
# 14       15      69  140000000
# 15       16     263   93000000
# 16       17      29  150000000
# 17       18    3233    8000000
# 18       19      99  250000000
# 19       20    1882   25000000
#
#                                                genres  \
# 0   [{"id": 28, "name": "Action"}, {"id": 53, "nam...
# 1   [{"id": 18, "name": "Drama"}, {"id": 28, "name...
# 2   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3   [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5   [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 6   [{"id": 18, "name": "Drama"}, {"id": 37, "name...
# 7   [{"id": 28, "name": "Action"}, {"id": 878, "na...
# 8   [{"id": 878, "name": "Science Fiction"}, {"id"...
# 9   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10                      [{"id": 18, "name": "Drama"}]
# 11  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 12  [{"id": 28, "name": "Action"}, {"id": 878, "na...
# 13  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 14  [{"id": 28, "name": "Action"}, {"id": 878, "na...
# 15  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 16  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 17  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 18  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 19  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
#
#                                         homepage      id  \
# 0          http://inceptionmovie.warnerbros.com/   27205
# 1   http://thedarkknight.warnerbros.com/dvdsite/     155
# 2                    http://www.avatarmovie.com/   19995
# 3              http://marvel.com/avengers_movie/   24428
# 4       http://www.foxmovies.com/movies/deadpool  293660
# 5              http://www.interstellarmovie.net/  157336
# 6                     http://unchainedmovie.com/   68718
# 7                    http://marvel.com/guardians  118340
# 8               http://www.thehungergames.movie/   70160
# 9                    http://www.madmaxmovie.com/   76341
# 10    http://www.foxmovies.com/movies/fight-club     550
# 11            http://www.thedarkknightrises.com/   49026
# 12              http://www.warnerbros.com/matrix     603
# 13                    http://marvel.com/ironman3   68721
# 14                  http://www.ironmanmovie.com/    1726
# 15                http://www.lordoftherings.net/     120
# 16                 http://www.jurassicworld.com/  135397
# 17                                           NaN     680
# 18                     http://www.thehobbit.com/   49051
# 19                                           NaN     278
#
#                                              keywords original_language  \
# 0   [{"id": 1014, "name": "loss of lover"}, {"id":...                en
# 1   [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 2   [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 3   [{"id": 242, "name": "new york"}, {"id": 5539,...                en
# 4   [{"id": 2095, "name": "anti hero"}, {"id": 307...                en
# 5   [{"id": 83, "name": "saving the world"}, {"id"...                en
# 6   [{"id": 801, "name": "bounty hunter"}, {"id": ...                en
# 7   [{"id": 8828, "name": "marvel comic"}, {"id": ...                en
# 8   [{"id": 3298, "name": "hallucination"}, {"id":...                en
# 9   [{"id": 2964, "name": "future"}, {"id": 3713, ...                en
# 10  [{"id": 825, "name": "support group"}, {"id": ...                en
# 11  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 12  [{"id": 83, "name": "saving the world"}, {"id"...                en
# 13  [{"id": 949, "name": "terrorist"}, {"id": 5597...                en
# 14  [{"id": 539, "name": "middle east"}, {"id": 61...                en
# 15  [{"id": 603, "name": "elves"}, {"id": 604, "na...                en
# 16  [{"id": 1299, "name": "monster"}, {"id": 1718,...                en
# 17  [{"id": 396, "name": "transporter"}, {"id": 14...                en
# 18  [{"id": 483, "name": "riddle"}, {"id": 603, "n...                en
# 19  [{"id": 378, "name": "prison"}, {"id": 417, "n...                en
#
#                                        original_title  \
# 0                                           Inception
# 1                                     The Dark Knight
# 2                                              Avatar
# 3                                        The Avengers
# 4                                            Deadpool
# 5                                        Interstellar
# 6                                    Django Unchained
# 7                             Guardians of the Galaxy
# 8                                    The Hunger Games
# 9                                  Mad Max: Fury Road
# 10                                         Fight Club
# 11                              The Dark Knight Rises
# 12                                         The Matrix
# 13                                         Iron Man 3
# 14                                           Iron Man
# 15  The Lord of the Rings: The Fellowship of the Ring
# 16                                     Jurassic World
# 17                                       Pulp Fiction
# 18                  The Hobbit: An Unexpected Journey
# 19                           The Shawshank Redemption
#
#                                              overview  ...  runtime  \
# 0   Cobb, a skilled thief who commits corporate es...  ...      148
# 1   Batman raises the stakes in his war on crime. ...  ...      152
# 2   In the 22nd century, a paraplegic Marine is di...  ...      162
# 3   When an unexpected enemy emerges and threatens...  ...      143
# 4   Deadpool tells the origin story of former Spec...  ...      108
# 5   Interstellar chronicles the adventures of a gr...  ...      169
# 6   With the help of a German bounty hunter, a fre...  ...      165
# 7   Light years from Earth, 26 years after being a...  ...      121
# 8   Every year in the ruins of what was once North...  ...      142
# 9   An apocalyptic story set in the furthest reach...  ...      120
# 10  A ticking-time-bomb insomniac and a slippery s...  ...      139
# 11  Following the death of District Attorney Harve...  ...      165
# 12  Set in the 22nd century, The Matrix tells the ...  ...      136
# 13  When Tony Stark's world is torn apart by a for...  ...      130
# 14  After being held captive in an Afghan cave, bi...  ...      126
# 15  Young hobbit Frodo Baggins, after inheriting a...  ...      178
# 16  Twenty-two years after the events of Jurassic ...  ...      124
# 17  A burger-loving hit man, his philosophical par...  ...      154
# 18  Bilbo Baggins, a hobbit enjoying his quiet lif...  ...      169
# 19  Framed in the 1940s for the double murder of h...  ...      142
#
#                                      spoken_languages    status  \
# 0   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 2   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 3            [{"iso_639_1": "en", "name": "English"}]  Released
# 4            [{"iso_639_1": "en", "name": "English"}]  Released
# 5            [{"iso_639_1": "en", "name": "English"}]  Released
# 6   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 7            [{"iso_639_1": "en", "name": "English"}]  Released
# 8            [{"iso_639_1": "en", "name": "English"}]  Released
# 9            [{"iso_639_1": "en", "name": "English"}]  Released
# 10           [{"iso_639_1": "en", "name": "English"}]  Released
# 11           [{"iso_639_1": "en", "name": "English"}]  Released
# 12           [{"iso_639_1": "en", "name": "English"}]  Released
# 13           [{"iso_639_1": "en", "name": "English"}]  Released
# 14  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 15           [{"iso_639_1": "en", "name": "English"}]  Released
# 16           [{"iso_639_1": "en", "name": "English"}]  Released
# 17  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 18           [{"iso_639_1": "en", "name": "English"}]  Released
# 19           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                               tagline  \
# 0                Your mind is the scene of the crime.
# 1                                     Why So Serious?
# 2                         Enter the World of Pandora.
# 3                             Some assembly required.
# 4             Witness the beginning of a happy ending
# 5   Mankind was born on Earth. It was never meant ...
# 6         Life, liberty and the pursuit of vengeance.
# 7                         All heroes start somewhere.
# 8                 May The Odds Be Ever In Your Favor.
# 9                                  What a Lovely Day.
# 10                            Mischief. Mayhem. Soap.
# 11                                    The Legend Ends
# 12                         Welcome to the Real World.
# 13                Unleash the power behind the armor.
# 14                 Heroes aren't born. They're built.
# 15                          One ring to rule them all
# 16                                  The park is open.
# 17  Just because you are a character doesn't mean ...
# 18  From the smallest beginnings come the greatest...
# 19  Fear can hold you prisoner. Hope can set you f...
#
#                                                 title  vote_average  \
# 0                                           Inception           8.1
# 1                                     The Dark Knight           8.2
# 2                                              Avatar           7.2
# 3                                        The Avengers           7.4
# 4                                            Deadpool           7.4
# 5                                        Interstellar           8.1
# 6                                    Django Unchained           7.8
# 7                             Guardians of the Galaxy           7.9
# 8                                    The Hunger Games           6.9
# 9                                  Mad Max: Fury Road           7.2
# 10                                         Fight Club           8.3
# 11                              The Dark Knight Rises           7.6
# 12                                         The Matrix           7.9
# 13                                         Iron Man 3           6.8
# 14                                           Iron Man           7.4
# 15  The Lord of the Rings: The Fellowship of the Ring           8.0
# 16                                     Jurassic World           6.5
# 17                                       Pulp Fiction           8.3
# 18                  The Hobbit: An Unexpected Journey           7.0
# 19                           The Shawshank Redemption           8.5
#
#    vote_count movie_id                                               cast  \
# 0       13752    27205  [{"cast_id": 1, "character": "Dom Cobb", "cred...
# 1       12002      155  [{"cast_id": 35, "character": "Bruce Wayne", "...
# 2       11800    19995  [{"cast_id": 242, "character": "Jake Sully", "...
# 3       11776    24428  [{"cast_id": 46, "character": "Tony Stark / Ir...
# 4       10995   293660  [{"cast_id": 99, "character": "Wade Wilson / D...
# 5       10867   157336  [{"cast_id": 9, "character": "Joseph Cooper", ...
# 6       10099    68718  [{"cast_id": 6, "character": "Django", "credit...
# 7        9742   118340  [{"cast_id": 1, "character": "Peter Quill / St...
# 8        9455    70160  [{"cast_id": 4, "character": "Katniss Everdeen...
# 9        9427    76341  [{"cast_id": 2, "character": "Max Rockatansky"...
# 10       9413      550  [{"cast_id": 4, "character": "The Narrator", "...
# 11       9106    49026  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 12       8907      603  [{"cast_id": 34, "character": "Thomas \"Neo\" ...
# 13       8806    68721  [{"cast_id": 40, "character": "Tony Stark / Ir...
# 14       8776     1726  [{"cast_id": 19, "character": "Tony Stark / Ir...
# 15       8705      120  [{"cast_id": 28, "character": "Frodo Baggins",...
# 16       8662   135397  [{"cast_id": 10, "character": "Owen Grady", "c...
# 17       8428      680  [{"cast_id": 2, "character": "Vincent Vega", "...
# 18       8297    49051  [{"cast_id": 6, "character": "Gandalf", "credi...
# 19       8205      278  [{"cast_id": 3, "character": "Andy Dufresne", ...
#
#                                                  crew
# 0   [{"credit_id": "56e8462cc3a368408400354c", "de...
# 1   [{"credit_id": "55a0eb4a925141296b0010f8", "de...
# 2   [{"credit_id": "52fe48009251416c750aca23", "de...
# 3   [{"credit_id": "52fe4495c3a368484e02b1cf", "de...
# 4   [{"credit_id": "56c986b2925141172f0068b6", "de...
# 5   [{"credit_id": "52fe4bbf9251416c910e4801", "de...
# 6   [{"credit_id": "5703f6a2c3a36869850001d9", "de...
# 7   [{"credit_id": "538ce329c3a3687155003358", "de...
# 8   [{"credit_id": "52fe47edc3a368484e0e0d2d", "de...
# 9   [{"credit_id": "577da370c3a36817f8003838", "de...
# 10  [{"credit_id": "55731b8192514111610027d7", "de...
# 11  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 12  [{"credit_id": "5831cc6d92514162d2027340", "de...
# 13  [{"credit_id": "52fe47a0c3a368484e0d15cb", "de...
# 14  [{"credit_id": "52fe4311c3a36847f8037f21", "de...
# 15  [{"credit_id": "52fe421ac3a36847f80043fb", "de...
# 16  [{"credit_id": "52fe4bf7c3a368484e1a0683", "de...
# 17  [{"credit_id": "52fe4269c3a36847f801caa3", "de...
# 18  [{"credit_id": "52fe4783c3a36847f8139fa5", "de...
# 19  [{"credit_id": "52fe4231c3a36847f800b153", "de...
#
# [20 rows x 25 columns]

# %%
# movies.to_csv('movies_new.csv', header=True, index=False, encoding='utf-8')

# %%
movies = movies[['movieId','genres','keywords','title','overview','cast','crew']]

# %%
movies.dropna(inplace=True)

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
movies.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 53, "name": "Thriller"}, {"id": 878, "name": "Science Fiction"}, {"id": 9648, "name": "Mystery"}, {"id": 12, "name": "Adventure"}]'

# %%
'''
Content based generation
'''
# Out:
# '\nContent based generation\n'

# %%
def convert(obj):
    L = []
    for i in ast.literal_eval(obj):
        L.append(i['name'])
    return L

# %%
movies['genres'] = movies['genres'].apply(convert)
movies['keywords'] = movies['keywords'].apply(convert)

# %%
def convertCast(obj):
    L = []
    counter = 0
    for i in ast.literal_eval(obj):
        if counter < 3:
            L.append(i['name'])
            counter+=1
        else:
            break;
    return L

# %%
movies['cast'] = movies['cast'].apply(convertCast)

# %%
def fetchDirector(obj):
    L = []
    for i in ast.literal_eval(obj):
        if i['job'] == 'Director':
            L.append(i['name'])
            break;
    return L

# %%
movies['crew'] = movies['crew'].apply(fetchDirector)

# %%
movies['overview'] = movies['overview'].apply(lambda x: x.split())

# %%
movies['genres'] = movies['genres'].apply(lambda x:[i.replace(" ","") for i in x])
movies['keywords'] = movies['keywords'].apply(lambda x:[i.replace(" ","") for i in x])
movies['cast'] = movies['cast'].apply(lambda x:[i.replace(" ","") for i in x])
movies['crew'] = movies['crew'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
newDf = movies[['movieId','title','tags']]

# %%
newDf['tags'] = newDf['tags'].apply(lambda x: " ".join(x))
# Out:
# C:\Users\otbho\AppData\Local\Temp/ipykernel_14436/3762652423.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newDf['tags'] = newDf['tags'].apply(lambda x: " ".join(x))

# %%
newDf['tags'] = newDf['tags'].apply(lambda x: x.lower())
# Out:
# C:\Users\otbho\AppData\Local\Temp/ipykernel_14436/2614462281.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newDf['tags'] = newDf['tags'].apply(lambda x: x.lower())

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y = []
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
newDf['tags'] = newDf['tags'].apply(stem)
# Out:
# C:\Users\otbho\AppData\Local\Temp/ipykernel_14436/877819958.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newDf['tags'] = newDf['tags'].apply(stem)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vectors = cv.fit_transform(newDf['tags']).toarray()

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)

# %%
def recommend(movieId):
    idx = newDf[newDf['movieId'] == movieId].index[0]
    distances = similarity[idx]
    movies_list = sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:11]
    L = []
    for i in movies_list:
        L.append(newDf.iloc[i[0]].title)
    return L

# %%
recommend(2)
# Out:
# ['The Dark Knight Rises',
#  'Batman Begins',
#  'Batman Returns',
#  'Batman',
#  'Batman Forever',
#  'Batman',
#  'Batman & Robin',
#  'Batman v Superman: Dawn of Justice',
#  'Law Abiding Citizen',
#  'The Usual Suspects']

# %%
movies.head(10)
# Out:
#    movieId                                             genres  \
# 0        1  [Action, Thriller, ScienceFiction, Mystery, Ad...
# 1        2                   [Drama, Action, Crime, Thriller]
# 2        3       [Action, Adventure, Fantasy, ScienceFiction]
# 3        4                [ScienceFiction, Action, Adventure]
# 4        5                        [Action, Adventure, Comedy]
# 5        6                 [Adventure, Drama, ScienceFiction]
# 6        7                                   [Drama, Western]
# 7        8                [Action, ScienceFiction, Adventure]
# 8        9               [ScienceFiction, Adventure, Fantasy]
# 9       10      [Action, Adventure, ScienceFiction, Thriller]
#
#                                             keywords                    title  \
# 0  [lossoflover, dream, kidnapping, sleep, subcon...                Inception
# 1  [dccomics, crimefighter, secretidentity, scare...          The Dark Knight
# 2  [cultureclash, future, spacewar, spacecolony, ...                   Avatar
# 3  [newyork, shield, marvelcomic, superhero, base...             The Avengers
# 4  [antihero, mercenary, marvelcomic, superhero, ...                 Deadpool
# 5  [savingtheworld, artificialintelligence, fathe...             Interstellar
# 6  [bountyhunter, hero, plantation, society, frie...         Django Unchained
# 7  [marvelcomic, spaceship, space, outerspace, or...  Guardians of the Galaxy
# 8  [hallucination, dystopia, femaleprotagonist, b...         The Hunger Games
# 9  [future, chase, post-apocalyptic, dystopia, au...       Mad Max: Fury Road
#
#                                             overview  \
# 0  [Cobb,, a, skilled, thief, who, commits, corpo...
# 1  [Batman, raises, the, stakes, in, his, war, on...
# 2  [In, the, 22nd, century,, a, paraplegic, Marin...
# 3  [When, an, unexpected, enemy, emerges, and, th...
# 4  [Deadpool, tells, the, origin, story, of, form...
# 5  [Interstellar, chronicles, the, adventures, of...
# 6  [With, the, help, of, a, German, bounty, hunte...
# 7  [Light, years, from, Earth,, 26, years, after,...
# 8  [Every, year, in, the, ruins, of, what, was, o...
# 9  [An, apocalyptic, story, set, in, the, furthes...
#
#                                                 cast                crew  \
# 0  [LeonardoDiCaprio, JosephGordon-Levitt, EllenP...  [ChristopherNolan]
# 1         [ChristianBale, HeathLedger, AaronEckhart]  [ChristopherNolan]
# 2      [SamWorthington, ZoeSaldana, SigourneyWeaver]      [JamesCameron]
# 3         [RobertDowneyJr., ChrisEvans, MarkRuffalo]        [JossWhedon]
# 4           [RyanReynolds, MorenaBaccarin, EdSkrein]         [TimMiller]
# 5  [MatthewMcConaughey, JessicaChastain, AnneHath...  [ChristopherNolan]
# 6      [JamieFoxx, ChristophWaltz, LeonardoDiCaprio]  [QuentinTarantino]
# 7             [ChrisPratt, ZoeSaldana, DaveBautista]         [JamesGunn]
# 8  [JenniferLawrence, JoshHutcherson, LiamHemsworth]          [GaryRoss]
# 9          [TomHardy, CharlizeTheron, NicholasHoult]      [GeorgeMiller]
#
#                                                 tags
# 0  [Cobb,, a, skilled, thief, who, commits, corpo...
# 1  [Batman, raises, the, stakes, in, his, war, on...
# 2  [In, the, 22nd, century,, a, paraplegic, Marin...
# 3  [When, an, unexpected, enemy, emerges, and, th...
# 4  [Deadpool, tells, the, origin, story, of, form...
# 5  [Interstellar, chronicles, the, adventures, of...
# 6  [With, the, help, of, a, German, bounty, hunte...
# 7  [Light, years, from, Earth,, 26, years, after,...
# 8  [Every, year, in, the, ruins, of, what, was, o...
# 9  [An, apocalyptic, story, set, in, the, furthes...

# %%
from joblib import dump
dump(similarity, 'model/content_based.joblib')
dump(newDf, 'model/movie_df.joblib')
# Out:
# ['model/movie_df.joblib']

# %%
# ratings.to_csv('ratings.csv')

# %%
'''
Top Recommendation
'''
# Out:
# '\nTop Recommendation\n'

# %%
def weighted_rating(v,m,R,C):
    return ( (v / (v + m)) * R) + ( (m / (v + m)) * C )

# %%
# pre processing
vote_count = (
    ratings
    .groupby('movieId',as_index=False)
    .agg( {'userId':'count', 'rating':'mean'} )
    )
vote_count.columns = ['movieId', 'vote_count', 'avg_rating']

# calcuate input parameters
C = np.mean(vote_count['avg_rating'])
m = np.percentile(vote_count['vote_count'], 70)
vote_count = vote_count[vote_count['vote_count'] >= m]
R = vote_count['avg_rating']
v = vote_count['vote_count']
vote_count['weighted_rating'] = weighted_rating(v,m,R,C)

# post processing
vote_count = vote_count.merge(movies, on = ['movieId'], how = 'left')
popular_items = vote_count.loc[:,['movieId','title', 'genres', 'overview','weighted_rating',]]
popular_items = popular_items.sort_values('weighted_rating',ascending=False)
popular_items = popular_items.head(10)

# %%
from joblib import dump
dump(popular_items, 'model/top_rated.joblib')
# Out:
# ['model/top_rated.joblib']

# %%
popular_items
# Out:
#      movieId                             title  \
# 152      547        Ace Ventura: Pet Detective
# 404     1422      The Texas Chain Saw Massacre
# 182      654                               xXx
# 318     1126                            Closer
# 93       346    Home Alone 2: Lost in New York
# 89       336                           Super 8
# 229      820  Ghost Rider: Spirit of Vengeance
# 373     1309             Thank You for Smoking
# 227      812                       Chicken Run
# 81       305                         127 Hours
#
#                                   genres  \
# 152                    [Comedy, Mystery]
# 404                             [Horror]
# 182        [Action, Adventure, Thriller]
# 318                     [Drama, Romance]
# 93    [Comedy, Family, Adventure, Crime]
# 89   [Thriller, ScienceFiction, Mystery]
# 229          [Action, Fantasy, Thriller]
# 373                      [Comedy, Drama]
# 227          [Animation, Comedy, Family]
# 81          [Adventure, Drama, Thriller]
#
#                                               overview  weighted_rating
# 152  [He's, Ace, Ventura:, Pet, Detective., Jim, Ca...         3.499807
# 404  [Five, friends, visiting, their, grandfather's...         3.499807
# 182  [Xander, Cage, is, your, standard, adrenaline,...         3.499807
# 318  [A, witty,, romantic,, and, very, dangerous, l...         3.499807
# 93   [Instead, of, flying, to, Florida, with, his, ...         3.249710
# 89   [In, 1979, Ohio,, several, youngsters, are, ma...         3.249710
# 229  [When, the, devil, resurfaces, with, aims, to,...         3.249710
# 373  [The, chief, spokesperson, and, lobbyist, Nick...         3.249710
# 227  [Having, been, hopelessly, repressed, and, fac...         3.249710
# 81   [The, true, story, of, mountain, climber, Aron...         3.249710

# %%
'''
CF Recommendation
'''
# Out:
# '\nCF Recommendation\n'

# %%
genre = movies['genres']
# get all possible genre
all_genre = set()
for c in genre:
    for i in c:
        all_genre.update(c)
#     distinct_genre = genre[c].str.lower().str.strip().unique()
#     all_genre.update(distinct_genre)
# all_genre.remove(None)
all_genre = list(all_genre)

# %%
from joblib import dump
dump(all_genre, 'model/genres.joblib')
# Out:
# ['model/genres.joblib']

# %%
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import csr_matrix

NUM_USERS = 100
NUM_MOVIES = 1500


# preprocess data
row = ratings['userId']
col = ratings['movieId']
data = ratings['rating']

# init user-item matrix
mat = csr_matrix((data, (row, col)))
mat.eliminate_zeros()

# calculate sparsity
sparsity = float(len(mat.nonzero()[0]))
sparsity /= (mat.shape[0] * mat.shape[1])
sparsity *= 100
print(f'Sparsity: {sparsity:4.2f}%. This means that {sparsity:4.2f}% of the user-item ratings have a value.')

# compute similarity
item_corr_mat = cosine_similarity(mat.T)
# Out:
# Sparsity: 0.34%. This means that 0.34% of the user-item ratings have a value.

# %%
from joblib import dump
dump(item_corr_mat, 'model/cf_model.joblib')
# Out:
# ['model/cf_model.joblib']

# %%
def top_k_items(item_id, top_k, corr_mat, map_name):
    # sort correlation value ascendingly and select top_k item_id
    top_items = corr_mat[item_id,:].argsort()[-top_k:][::-1] 
    top_items = [map_name[e] for e in top_items] 

    return top_items

# %%
# get top-k similar items
ind2name = {ind:name for ind,name in enumerate(item_genre_mat.index)}
name2ind = {v:k for k,v in ind2name.items()}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14436/1827142642.py in <module>
#       1 # get top-k similar items
# ----> 2 ind2name = {ind:name for ind,name in enumerate(item_genre_mat.index)}
#       3 name2ind = {v:k for k,v in ind2name.items()}
#
# NameError: name 'item_genre_mat' is not defined

# %%
def getCfRecommendations(movieId):
#     if movie_cf_mat is None:      
#         r = open('model/cf_memory.pkl', 'rb')
#         movie_cf_mat = pickle.load(r)
#         print('loaded cf')
#         r.close()
    similar_items = top_k_items(name2ind[movieId],
                            top_k = 10,
                            corr_mat = item_corr_mat,
                            map_name = ind2name)
    if(movieId in similar_items):
        similar_items.remove(int(movieId))
    res = movies.loc[movies['movieId'].isin(similar_items)]
    return res

# %%
getCfRecommendations(1484)

# %%
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# import gc

# from collections import defaultdict

# # synthesize data
# NUM_USERS = 101
# NUM_ITEMS = 1501
# user_id = np.arange(start = 0, stop = NUM_USERS)
# item_id = np.arange(start = 0, stop = NUM_ITEMS)
# np.random.seed(42)

# user_item_dict = defaultdict(list)

# for id in user_id:
    
#     # random the number of item generation
#     # for each user, random 3 to 5 items to be rated.
#     num_rand_item = np.random.randint(low = 3, high = 8)

#     # random from the item_id
#     rand_items = np.random.choice(item_id, size = num_rand_item, replace = False)

#     # random rating for each itme_id
#     rand_rating = np.random.randint(low = 1, high = 5, size = num_rand_item)

#     # collect the user-item paris.
#     for uid, iid,rating in zip([id] * num_rand_item, rand_items, rand_rating):
#         user_item_dict['userid'].append(uid)
#         user_item_dict['movieId'].append(iid)
#         user_item_dict['rating'].append(rating)

# # prepare dataframe
# ratings = pd.DataFrame(user_item_dict)
# print("Rating Dataframe")
# ratings[['userid','movieId']] = ratings[['userid','movieId']].astype(str)
# display(ratings.head())
# Out:
# Rating Dataframe
#   userid movieId  rating
# 0      0      51       1
# 1      0    1465       4
# 2      0     184       3
# 3      0    1000       4
# 4      0     746       3

# %%
# ratings.to_csv('ratings.csv',index=False)
