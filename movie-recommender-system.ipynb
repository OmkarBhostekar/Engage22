# %%
import numpy as np
import pandas as pd
import ast

# %%
movies_raw = pd.read_csv('dataset/movies.csv')
credits_raw = pd.read_csv('dataset/credits.csv')
ratings = pd.read_csv('dataset/ratings.csv')

# %%
movies = movies_raw.merge(credits_raw,on='title')

# %%
# movies.dropna()

# %%
# movies = pd.read_csv('movies_new.csv')

# %%
# movies.dropna()
# movies = movies.sort_values(by = 'vote_count',ascending=False)

# %%
# movies = movies.head(1500)

# %%
movies.head(20)
# Out:
#     movieId  tmdbId     budget  \
# 0         1   27205  160000000
# 1         2     155  185000000
# 2         3   19995  237000000
# 3         4   24428  220000000
# 4         5  293660   58000000
# 5         6  157336  165000000
# 6         7   68718  100000000
# 7         8  283995  170000000
# 8         9   70160   75000000
# 9        10   76341  150000000
# 10       11     550   63000000
# 11       12   49026  250000000
# 12       13  624860   63000000
# 13       14   68721  200000000
# 14       15    1726  140000000
# 15       16     120   93000000
# 16       17  135397  150000000
# 17       18     680    8000000
# 18       19   49051  250000000
# 19       20     278   25000000
#
#                                                genres  \
# 0   [{"id": 28, "name": "Action"}, {"id": 53, "nam...
# 1   [{"id": 18, "name": "Drama"}, {"id": 28, "name...
# 2   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3   [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5   [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 6   [{"id": 18, "name": "Drama"}, {"id": 37, "name...
# 7   [{"id": 28, "name": "Action"}, {"id": 878, "na...
# 8   [{"id": 878, "name": "Science Fiction"}, {"id"...
# 9   [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10                      [{"id": 18, "name": "Drama"}]
# 11  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 12  [{"id": 28, "name": "Action"}, {"id": 878, "na...
# 13  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 14  [{"id": 28, "name": "Action"}, {"id": 878, "na...
# 15  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 16  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 17  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 18  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 19  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
#
#                                         homepage  \
# 0          http://inceptionmovie.warnerbros.com/
# 1   http://thedarkknight.warnerbros.com/dvdsite/
# 2                    http://www.avatarmovie.com/
# 3              http://marvel.com/avengers_movie/
# 4       http://www.foxmovies.com/movies/deadpool
# 5              http://www.interstellarmovie.net/
# 6                     http://unchainedmovie.com/
# 7                    http://marvel.com/guardians
# 8               http://www.thehungergames.movie/
# 9                    http://www.madmaxmovie.com/
# 10    http://www.foxmovies.com/movies/fight-club
# 11            http://www.thedarkknightrises.com/
# 12              http://www.warnerbros.com/matrix
# 13                    http://marvel.com/ironman3
# 14                  http://www.ironmanmovie.com/
# 15                http://www.lordoftherings.net/
# 16                 http://www.jurassicworld.com/
# 17                                           NaN
# 18                     http://www.thehobbit.com/
# 19                                           NaN
#
#                                              keywords original_language  \
# 0   [{"id": 1014, "name": "loss of lover"}, {"id":...                en
# 1   [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 2   [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 3   [{"id": 242, "name": "new york"}, {"id": 5539,...                en
# 4   [{"id": 2095, "name": "anti hero"}, {"id": 307...                en
# 5   [{"id": 83, "name": "saving the world"}, {"id"...                en
# 6   [{"id": 801, "name": "bounty hunter"}, {"id": ...                en
# 7   [{"id": 8828, "name": "marvel comic"}, {"id": ...                en
# 8   [{"id": 3298, "name": "hallucination"}, {"id":...                en
# 9   [{"id": 2964, "name": "future"}, {"id": 3713, ...                en
# 10  [{"id": 825, "name": "support group"}, {"id": ...                en
# 11  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 12  [{"id": 83, "name": "saving the world"}, {"id"...                en
# 13  [{"id": 949, "name": "terrorist"}, {"id": 5597...                en
# 14  [{"id": 539, "name": "middle east"}, {"id": 61...                en
# 15  [{"id": 603, "name": "elves"}, {"id": 604, "na...                en
# 16  [{"id": 1299, "name": "monster"}, {"id": 1718,...                en
# 17  [{"id": 396, "name": "transporter"}, {"id": 14...                en
# 18  [{"id": 483, "name": "riddle"}, {"id": 603, "n...                en
# 19  [{"id": 378, "name": "prison"}, {"id": 417, "n...                en
#
#                                        original_title  \
# 0                                           Inception
# 1                                     The Dark Knight
# 2                                              Avatar
# 3                                        The Avengers
# 4                                            Deadpool
# 5                                        Interstellar
# 6                                    Django Unchained
# 7                             Guardians of the Galaxy
# 8                                    The Hunger Games
# 9                                  Mad Max: Fury Road
# 10                                         Fight Club
# 11                              The Dark Knight Rises
# 12                                         The Matrix
# 13                                         Iron Man 3
# 14                                           Iron Man
# 15  The Lord of the Rings: The Fellowship of the Ring
# 16                                     Jurassic World
# 17                                       Pulp Fiction
# 18                  The Hobbit: An Unexpected Journey
# 19                           The Shawshank Redemption
#
#                                              overview  \
# 0   Cobb, a skilled thief who commits corporate es...
# 1   Batman raises the stakes in his war on crime. ...
# 2   In the 22nd century, a paraplegic Marine is di...
# 3   When an unexpected enemy emerges and threatens...
# 4   Deadpool tells the origin story of former Spec...
# 5   Interstellar chronicles the adventures of a gr...
# 6   With the help of a German bounty hunter, a fre...
# 7   Light years from Earth, 26 years after being a...
# 8   Every year in the ruins of what was once North...
# 9   An apocalyptic story set in the furthest reach...
# 10  A ticking-time-bomb insomniac and a slippery s...
# 11  Following the death of District Attorney Harve...
# 12  Set in the 22nd century, The Matrix tells the ...
# 13  When Tony Stark's world is torn apart by a for...
# 14  After being held captive in an Afghan cave, bi...
# 15  Young hobbit Frodo Baggins, after inheriting a...
# 16  Twenty-two years after the events of Jurassic ...
# 17  A burger-loving hit man, his philosophical par...
# 18  Bilbo Baggins, a hobbit enjoying his quiet lif...
# 19  Framed in the 1940s for the double murder of h...
#
#                          poster_path  ... runtime  \
# 0   /edv5CZvWj09upOsy2Y6IwDhK8bt.jpg  ...     148
# 1   /qJ2tW6WMUDux911r6m7haRef0WH.jpg  ...     152
# 2   /jRXYjXNq0Cs2TcJjLkki24MLp7u.jpg  ...     162
# 3    /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg  ...     143
# 4   /fSRb7vyIP8rQpL0I47P3qUsEKX3.jpg  ...     108
# 5   /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg  ...     169
# 6   /7oWY8VDWW7thTzWh3OKYRkWUlD5.jpg  ...     165
# 7   /y4MBh0EjBlMuOzv9axM4qJlmhzz.jpg  ...     121
# 8   /1ewwtjqAcwZ5abr2X7coGN0UwaI.jpg  ...     142
# 9   /8tZYtuWezp8JbcsvHYO0O46tFbo.jpg  ...     120
# 10  /pB8BM7pdSp6B6Ih7QZ4DrQ3PmJK.jpg  ...     139
# 11  /85cWkCVftiVs0BVey6pxX8uNmLt.jpg  ...     165
# 12  /8c4a8kE7PizaGQQnditMmI1xbRp.jpg  ...     136
# 13  /qhPtAc1TKbMPqNvcdXSOn9Bn7hZ.jpg  ...     130
# 14  /78lPtwv72eTNqFW9COBYI0dWDJa.jpg  ...     126
# 15  /6oom5QYQ2yQTMJIbnvbkBL9cHo6.jpg  ...     178
# 16  /rhr4y79GpxQF9IsfJItRXVaoGs4.jpg  ...     124
# 17  /fIE3lAGcZDV1G6XM5KmuWnNsPp1.jpg  ...     154
# 18  /yHA9Fc37VmpUA5UncTxxo3rTGVA.jpg  ...     169
# 19  /q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg  ...     142
#
#                                      spoken_languages    status  \
# 0   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 2   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 3            [{"iso_639_1": "en", "name": "English"}]  Released
# 4            [{"iso_639_1": "en", "name": "English"}]  Released
# 5            [{"iso_639_1": "en", "name": "English"}]  Released
# 6   [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 7            [{"iso_639_1": "en", "name": "English"}]  Released
# 8            [{"iso_639_1": "en", "name": "English"}]  Released
# 9            [{"iso_639_1": "en", "name": "English"}]  Released
# 10           [{"iso_639_1": "en", "name": "English"}]  Released
# 11           [{"iso_639_1": "en", "name": "English"}]  Released
# 12           [{"iso_639_1": "en", "name": "English"}]  Released
# 13           [{"iso_639_1": "en", "name": "English"}]  Released
# 14  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 15           [{"iso_639_1": "en", "name": "English"}]  Released
# 16           [{"iso_639_1": "en", "name": "English"}]  Released
# 17  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 18           [{"iso_639_1": "en", "name": "English"}]  Released
# 19           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                               tagline  \
# 0                Your mind is the scene of the crime.
# 1                                     Why So Serious?
# 2                         Enter the World of Pandora.
# 3                             Some assembly required.
# 4             Witness the beginning of a happy ending
# 5   Mankind was born on Earth. It was never meant ...
# 6         Life, liberty and the pursuit of vengeance.
# 7                         All heroes start somewhere.
# 8                 May The Odds Be Ever In Your Favor.
# 9                                  What a Lovely Day.
# 10                            Mischief. Mayhem. Soap.
# 11                                    The Legend Ends
# 12                         Welcome to the Real World.
# 13                Unleash the power behind the armor.
# 14                 Heroes aren't born. They're built.
# 15                          One ring to rule them all
# 16                                  The park is open.
# 17  Just because you are a character doesn't mean ...
# 18  From the smallest beginnings come the greatest...
# 19  Fear can hold you prisoner. Hope can set you f...
#
#                                                 title  vote_average  \
# 0                                           Inception           8.1
# 1                                     The Dark Knight           8.2
# 2                                              Avatar           7.2
# 3                                        The Avengers           7.4
# 4                                            Deadpool           7.4
# 5                                        Interstellar           8.1
# 6                                    Django Unchained           7.8
# 7                             Guardians of the Galaxy           7.9
# 8                                    The Hunger Games           6.9
# 9                                  Mad Max: Fury Road           7.2
# 10                                         Fight Club           8.3
# 11                              The Dark Knight Rises           7.6
# 12                                         The Matrix           7.9
# 13                                         Iron Man 3           6.8
# 14                                           Iron Man           7.4
# 15  The Lord of the Rings: The Fellowship of the Ring           8.0
# 16                                     Jurassic World           6.5
# 17                                       Pulp Fiction           8.3
# 18                  The Hobbit: An Unexpected Journey           7.0
# 19                           The Shawshank Redemption           8.5
#
#     vote_count movie_id                                               cast  \
# 0        13752    27205  [{"cast_id": 1, "character": "Dom Cobb", "cred...
# 1        12002      155  [{"cast_id": 35, "character": "Bruce Wayne", "...
# 2        11800    19995  [{"cast_id": 242, "character": "Jake Sully", "...
# 3        11776    24428  [{"cast_id": 46, "character": "Tony Stark / Ir...
# 4        10995   293660  [{"cast_id": 99, "character": "Wade Wilson / D...
# 5        10867   157336  [{"cast_id": 9, "character": "Joseph Cooper", ...
# 6        10099    68718  [{"cast_id": 6, "character": "Django", "credit...
# 7         9742   118340  [{"cast_id": 1, "character": "Peter Quill / St...
# 8         9455    70160  [{"cast_id": 4, "character": "Katniss Everdeen...
# 9         9427    76341  [{"cast_id": 2, "character": "Max Rockatansky"...
# 10        9413      550  [{"cast_id": 4, "character": "The Narrator", "...
# 11        9106    49026  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 12        8907      603  [{"cast_id": 34, "character": "Thomas \"Neo\" ...
# 13        8806    68721  [{"cast_id": 40, "character": "Tony Stark / Ir...
# 14        8776     1726  [{"cast_id": 19, "character": "Tony Stark / Ir...
# 15        8705      120  [{"cast_id": 28, "character": "Frodo Baggins",...
# 16        8662   135397  [{"cast_id": 10, "character": "Owen Grady", "c...
# 17        8428      680  [{"cast_id": 2, "character": "Vincent Vega", "...
# 18        8297    49051  [{"cast_id": 6, "character": "Gandalf", "credi...
# 19        8205      278  [{"cast_id": 3, "character": "Andy Dufresne", ...
#
#                                                  crew
# 0   [{"credit_id": "56e8462cc3a368408400354c", "de...
# 1   [{"credit_id": "55a0eb4a925141296b0010f8", "de...
# 2   [{"credit_id": "52fe48009251416c750aca23", "de...
# 3   [{"credit_id": "52fe4495c3a368484e02b1cf", "de...
# 4   [{"credit_id": "56c986b2925141172f0068b6", "de...
# 5   [{"credit_id": "52fe4bbf9251416c910e4801", "de...
# 6   [{"credit_id": "5703f6a2c3a36869850001d9", "de...
# 7   [{"credit_id": "538ce329c3a3687155003358", "de...
# 8   [{"credit_id": "52fe47edc3a368484e0e0d2d", "de...
# 9   [{"credit_id": "577da370c3a36817f8003838", "de...
# 10  [{"credit_id": "55731b8192514111610027d7", "de...
# 11  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 12  [{"credit_id": "5831cc6d92514162d2027340", "de...
# 13  [{"credit_id": "52fe47a0c3a368484e0d15cb", "de...
# 14  [{"credit_id": "52fe4311c3a36847f8037f21", "de...
# 15  [{"credit_id": "52fe421ac3a36847f80043fb", "de...
# 16  [{"credit_id": "52fe4bf7c3a368484e1a0683", "de...
# 17  [{"credit_id": "52fe4269c3a36847f801caa3", "de...
# 18  [{"credit_id": "52fe4783c3a36847f8139fa5", "de...
# 19  [{"credit_id": "52fe4231c3a36847f800b153", "de...
#
# [20 rows x 26 columns]

# %%
# movies.to_csv('movies_new.csv', header=True, index=False, encoding='utf-8')

# %%
movies = movies[['movieId','genres','keywords','title','overview','cast','crew','tmdbId']]

# %%
movies.dropna(inplace=True)

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
movies.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 53, "name": "Thriller"}, {"id": 878, "name": "Science Fiction"}, {"id": 9648, "name": "Mystery"}, {"id": 12, "name": "Adventure"}]'

# %%
'''
Content based generation
'''
# Out:
# '\nContent based generation\n'

# %%
def convert(obj):
    L = []
    for i in ast.literal_eval(obj):
        L.append(i['name'])
    return L

# %%
movies['genres'] = movies['genres'].apply(convert)
movies['keywords'] = movies['keywords'].apply(convert)

# %%
def convertCast(obj):
    L = []
    counter = 0
    for i in ast.literal_eval(obj):
        if counter < 3:
            L.append(i['name'])
            counter+=1
        else:
            break;
    return L

# %%
movies['cast'] = movies['cast'].apply(convertCast)

# %%
def fetchDirector(obj):
    L = []
    for i in ast.literal_eval(obj):
        if i['job'] == 'Director':
            L.append(i['name'])
            break;
    return L

# %%
movies['crew'] = movies['crew'].apply(fetchDirector)

# %%
movies['overview'] = movies['overview'].apply(lambda x: x.split())

# %%
movies['genres'] = movies['genres'].apply(lambda x:[i.replace(" ","") for i in x])
movies['keywords'] = movies['keywords'].apply(lambda x:[i.replace(" ","") for i in x])
movies['cast'] = movies['cast'].apply(lambda x:[i.replace(" ","") for i in x])
movies['crew'] = movies['crew'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
movies['tags'] = movies['overview'] + movies['genres'] + movies['keywords'] + movies['cast'] + movies['crew']

# %%
newDf = movies[['movieId','title','tags','tmdbId']]

# %%
newDf['tags'] = newDf['tags'].apply(lambda x: " ".join(x))
# Out:
# C:\Users\otbho\AppData\Local\Temp/ipykernel_7944/3762652423.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newDf['tags'] = newDf['tags'].apply(lambda x: " ".join(x))

# %%
newDf['tags'] = newDf['tags'].apply(lambda x: x.lower())
# Out:
# C:\Users\otbho\AppData\Local\Temp/ipykernel_7944/2614462281.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newDf['tags'] = newDf['tags'].apply(lambda x: x.lower())

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y = []
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
newDf['tags'] = newDf['tags'].apply(stem)
# Out:
# C:\Users\otbho\AppData\Local\Temp/ipykernel_7944/877819958.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newDf['tags'] = newDf['tags'].apply(stem)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vectors = cv.fit_transform(newDf['tags']).toarray()

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)

# %%
def recommend(movieId):
    idx = newDf[newDf['movieId'] == movieId].index[0]
    distances = similarity[idx]
    movies_list = sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:11]
    L = []
    for i in movies_list:
        L.append(movies.iloc[i[0]].title)
    return L

# %%
recommend(21)
# Out:
# ['The Lord of the Rings: The Two Towers',
#  'The Hobbit: The Battle of the Five Armies',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'The Hobbit: An Unexpected Journey',
#  'The Hobbit: The Desolation of Smaug',
#  'Warcraft',
#  'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#  'Brave',
#  'Underworld: Rise of the Lycans',
#  'The Scorpion King']

# %%
newDf
# Out:
#       movieId                    title  \
# 0           1                Inception
# 1           2          The Dark Knight
# 2           3                   Avatar
# 3           4             The Avengers
# 4           5                 Deadpool
# ...       ...                      ...
# 1497     1496  xXx: State of the Union
# 1498     1497              The Wolfman
# 1499     1498                  Payback
# 1500     1499                 Child 44
# 1501     1500              Wall Street
#
#                                                    tags  tmdbId
# 0     cobb, a skill thief who commit corpor espionag...   27205
# 1     batman rais the stake in hi war on crime. with...     155
# 2     in the 22nd century, a parapleg marin is dispa...   19995
# 3     when an unexpect enemi emerg and threaten glob...   24428
# 4     deadpool tell the origin stori of former speci...  293660
# ...                                                 ...     ...
# 1497  ice cube star as dariu stone, a thrill-seek tr...   11679
# 1498  lawrenc talbot, an american man on a visit to ...    7978
# 1499  with friend like these, who need enemies? that...    2112
# 1500  set in stalin-era soviet union, a disgrac mgb ...  181283
# 1501  a young and impati stockbrok is will to do any...  106646
#
# [1502 rows x 4 columns]

# %%
from joblib import dump
dump(similarity, 'model/content_based.joblib')
dump(newDf, 'model/movie_df.joblib')
# Out:
# ['model/movie_df.joblib']

# %%
# ratings.to_csv('ratings.csv')

# %%
'''
Top Recommendation
'''
# Out:
# '\nTop Recommendation\n'

# %%
def weighted_rating(v,m,R,C):
    return ( (v / (v + m)) * R) + ( (m / (v + m)) * C )

# %%
# pre processing
vote_count = (
    ratings
    .groupby('movieId',as_index=False)
    .agg( {'userId':'count', 'rating':'mean'} )
    )
vote_count.columns = ['movieId', 'vote_count', 'avg_rating']

# calcuate input parameters
C = np.mean(vote_count['avg_rating'])
m = np.percentile(vote_count['vote_count'], 70)
vote_count = vote_count[vote_count['vote_count'] >= m]
R = vote_count['avg_rating']
v = vote_count['vote_count']
vote_count['weighted_rating'] = weighted_rating(v,m,R,C)

# post processing
vote_count = vote_count.merge(movies_raw, on = ['movieId'], how = 'left')
popular_items = vote_count.loc[:,['movieId','tmdbId','title','poster_path','backdrop_path','weighted_rating']]
popular_items = popular_items.sort_values('weighted_rating',ascending=False)
popular_items = popular_items.head(10)

# %%
from joblib import dump
dump(popular_items, 'model/top_rated.joblib')
# Out:
# ['model/top_rated.joblib']

# %%
popular_items
# Out:
#     movieId  tmdbId                                              title  \
# 9        20     278                           The Shawshank Redemption
# 18       55     238                                      The Godfather
# 1         2     155                                    The Dark Knight
# 10       21     122      The Lord of the Rings: The Return of the King
# 5        13  624860                                         The Matrix
# 7        16     120  The Lord of the Rings: The Fellowship of the Ring
# 4         6  157336                                       Interstellar
# 0         1   27205                                          Inception
# 3         4   24428                                       The Avengers
# 2         3   19995                                             Avatar
#
#                          poster_path                     backdrop_path  \
# 9   /q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg  /iNh3BivHyg5sQRPP1KOkzguEX0H.jpg
# 18  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg  /AbgEQO2mneCSOc8CSnOMa8pBS8I.jpg
# 1   /qJ2tW6WMUDux911r6m7haRef0WH.jpg  /6fA9nie4ROlkyZAUlgKNjGNCbHG.jpg
# 10  /rCzpDGLbOoPwLjy3OAm5NUPOTrC.jpg  /lXhgCODAbBXL5buk9yEmTpOoOgR.jpg
# 5   /8c4a8kE7PizaGQQnditMmI1xbRp.jpg  /eNI7PtK6DEYgZmHWP9gQNuff8pv.jpg
# 7   /6oom5QYQ2yQTMJIbnvbkBL9cHo6.jpg  /vRQnzOn4HjIMX4LBq9nHhFXbsSu.jpg
# 4   /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg
# 0   /edv5CZvWj09upOsy2Y6IwDhK8bt.jpg  /ztZ4vw151mw04Bg6rqJLQGBAmvn.jpg
# 3    /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg  /nNmJRkg8wWnRmzQDe2FwKbPIsJV.jpg
# 2   /jRXYjXNq0Cs2TcJjLkki24MLp7u.jpg  /jlQJDD0L5ZojjlS0KYnApdO0n19.jpg
#
#     weighted_rating
# 9          4.686370
# 18         4.595461
# 1          4.504552
# 10         4.413643
# 5          4.140916
# 7          4.129173
# 4          4.050007
# 0          3.962506
# 3          3.868188
# 2          3.712506

# %%
'''
CF Recommendation
'''
# Out:
# '\nCF Recommendation\n'

# %%
genre = movies['genres']
# get all possible genre
all_genre = set()
for c in genre:
    for i in c:
        all_genre.update(c)
#     distinct_genre = genre[c].str.lower().str.strip().unique()
#     all_genre.update(distinct_genre)
# all_genre.remove(None)
all_genre = list(all_genre)

# %%
from joblib import dump
dump(all_genre, 'model/genres.joblib')
# Out:
# ['model/genres.joblib']

# %%
# create item-genre matrix
item_genre_mat = movies[['movieId', 'genres']].copy()
item_genre_mat['genres'] = item_genre_mat['genres'].apply(lambda x: ''.join(x))

# OHE the genres column
for genre in all_genre:
    item_genre_mat[genre] = np.where(item_genre_mat['genres'].str.contains(genre), 1, 0)
item_genre_mat = item_genre_mat.drop(['genres'], axis=1)
item_genre_mat = item_genre_mat.set_index('movieId')

# %%
from joblib import dump
dump(item_genre_mat, 'model/item_genre_mat.joblib')
# Out:
# ['model/item_genre_mat.joblib']

# %%
from scipy.sparse import csr_matrix
USER_COL = 'userId'
ITEM_COL = 'movieId'
RATING_COL = 'rating'
# preprocess data
row = ratings[USER_COL]
col = ratings[ITEM_COL]
data = ratings[RATING_COL]

# init user-item matrix
mat = csr_matrix((data, (row, col)))
mat.eliminate_zeros()

# %%
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import csr_matrix

NUM_USERS = 100
NUM_MOVIES = 1500


# preprocess data
row = ratings['userId']
col = ratings['movieId']
data = ratings['rating']

# init user-item matrix
mat = csr_matrix((data, (row, col)))
mat.eliminate_zeros()

# calculate sparsity
sparsity = float(len(mat.nonzero()[0]))
sparsity /= (mat.shape[0] * mat.shape[1])
sparsity *= 100
print(f'Sparsity: {sparsity:4.2f}%. This means that {sparsity:4.2f}% of the user-item ratings have a value.')

# compute similarity
item_corr_mat = cosine_similarity(mat.T)
# Out:
# Sparsity: 0.37%. This means that 0.37% of the user-item ratings have a value.

# %%
from joblib import dump
dump(item_corr_mat, 'model/cf_model.joblib')
# Out:
# ['model/cf_model.joblib']

# %%
def top_k_items(item_id, top_k, corr_mat, map_name):
    # sort correlation value ascendingly and select top_k item_id
    top_items = corr_mat[item_id,:].argsort()[-top_k:][::-1] 
    top_items = [map_name[e] for e in top_items] 

    return top_items

# %%
# get top-k similar items
ind2name = {ind:name for ind,name in enumerate(item_genre_mat.index)}
name2ind = {v:k for k,v in ind2name.items()}

# %%
def getCfRecommendations(movieId):
#     if movie_cf_mat is None:      
#         r = open('model/cf_memory.pkl', 'rb')
#         movie_cf_mat = pickle.load(r)
#         print('loaded cf')
#         r.close()
    similar_items = top_k_items(name2ind[movieId],
                            top_k = 10,
                            corr_mat = item_corr_mat,
                            map_name = ind2name)
    if(movieId in similar_items):
        similar_items.remove(int(movieId))
    res = movies.loc[movies['movieId'].isin(similar_items)]
    return res

# %%
getCfRecommendations(16)
# Out:
#       movieId                               genres  \
# 493       492              [Drama, ScienceFiction]
# 494       493        [Action, Adventure, Thriller]
# 495       494              [ScienceFiction, Drama]
# 496       495              [History, Romance, War]
# 497       496                              [Drama]
# 498       497  [Adventure, Comedy, ScienceFiction]
# 499       498   [Thriller, ScienceFiction, Action]
# 500       499           [Action, Adventure, Crime]
# 502       501     [Comedy, Action, ScienceFiction]
# 1499     1498     [Drama, Action, Thriller, Crime]
#
#                                                keywords              title  \
# 493   [dystopia, blackandwhite, basedonyoungadultnovel]          The Giver
# 494   [cia, armsdealer, sequel, rescuemission, hospi...  The Expendables 3
# 495   [moon, artificialintelligence, clone, isolatio...               Moon
# 496   [nurse, patriotism, hawaii, worldwarii, pilot,...       Pearl Harbor
# 497   [underdog, philadelphia, transporter, italo-am...              Rocky
# 498   [sandiego, area51, alienspacecraft, hitwithach...               Paul
# 499   [darkness, dystopia, comet, alienlife-form, su...        Pitch Black
# 500   [bomb, airport, bus, busride, highway, bombpla...              Speed
# 502        [endoftheworld, apocalypse, trilogy, homage]    The World's End
# 1499                 [newyork, heroin, money, criminal]            Payback
#
#                                                overview  \
# 493   [In, a, seemingly, perfect, community,, withou...
# 494   [Barney,, Christmas, and, the, rest, of, the, ...
# 495   [With, only, three, weeks, left, in, his, thre...
# 496   [The, lifelong, friendship, between, Rafe, McC...
# 497   [When, world, heavyweight, boxing, champion,, ...
# 498   [For, the, past, 60, years,, a, space-travelin...
# 499   [When, their, ship, crash-lands, on, a, remote...
# 500   [Los, Angeles, SWAT, cop, Jack, Traven, is, up...
# 502   [Five, friends, who, reunite, in, an, attempt,...
# 1499  [With, friends, like, these,, who, needs, enem...
#
#                                                  cast              crew  \
# 493       [JeffBridges, MerylStreep, BrentonThwaites]    [PhillipNoyce]
# 494   [SylvesterStallone, JasonStatham, HarrisonFord]   [PatrickHughes]
# 495   [SamRockwell, KevinSpacey, DominiqueMcElligott]     [DuncanJones]
# 496        [BenAffleck, JoshHartnett, KateBeckinsale]      [MichaelBay]
# 497        [SylvesterStallone, TaliaShire, BurtYoung]  [JohnG.Avildsen]
# 498                 [SethRogen, SimonPegg, NickFrost]     [GregMottola]
# 499            [VinDiesel, RadhaMitchell, ColeHauser]      [DavidTwohy]
# 500        [KeanuReeves, DennisHopper, SandraBullock]       [JandeBont]
# 502             [SimonPegg, NickFrost, MartinFreeman]     [EdgarWright]
# 1499       [MelGibson, KrisKristofferson, GreggHenry]  [BrianHelgeland]
#
#       tmdbId                                               tags
# 493   227156  [In, a, seemingly, perfect, community,, withou...
# 494   138103  [Barney,, Christmas, and, the, rest, of, the, ...
# 495   580096  [With, only, three, weeks, left, in, his, thre...
# 496      676  [The, lifelong, friendship, between, Rafe, McC...
# 497     1366  [When, world, heavyweight, boxing, champion,, ...
# 498    39513  [For, the, past, 60, years,, a, space-travelin...
# 499     2787  [When, their, ship, crash-lands, on, a, remote...
# 500   136797  [Los, Angeles, SWAT, cop, Jack, Traven, is, up...
# 502   107985  [Five, friends, who, reunite, in, an, attempt,...
# 1499    2112  [With, friends, like, these,, who, needs, enem...

# %%
'''
Funk MF Model
'''

# %%
from surprise import SVD, accuracy
from surprise import Dataset, Reader
from surprise.model_selection import cross_validate
from surprise.model_selection.split import train_test_split

# def pred2dict(predictions, top_k=None):
    
#     rec_dict = defaultdict(list)
#     for user_id, item_id, actual_rating, pred_rating, _ in predictions:
#         rec_dict[user_id].append((item_id, pred_rating))        
        
#     return rec_dict

# def get_top_k_recommendation(rec_dict, user_id, top_k, ind2name):
    
#     pred_ratings = rec_dict[user_id]
#     # sort descendingly by pred_rating
#     pred_ratings = sorted(pred_ratings, key=lambda x: x[1], reverse=True)
#     pred_ratings = pred_ratings[:top_k]
#     recs = [ind2name[e[0]] for e in pred_ratings]
    
#     return recs

# prepare train and test sets
reader = Reader(rating_scale=(1,10))
data = Dataset.load_from_df(ratings, reader)
train, test = train_test_split(data, test_size=.2, random_state=42)

# init and fit the funk mf model
algo = SVD(random_state = 42)
algo.fit(train)
pred = algo.test(test);

# evaluation the test set
accuracy.rmse(pred)

# extract the item features from algo
movie_fmf_mat = cosine_similarity(algo.qi)

similar_items = top_k_items(name2ind[16],
                            top_k = 10,
                            corr_mat = movie_fmf_mat,
                            map_name = ind2name)

display(movies.loc[movies[ITEM_COL].isin(similar_items)])

# del movie_fmf_mat
# gc.collect();
# Out:
# RMSE: 1.0925
#      movieId                               genres  \
# 11        12     [Action, Crime, Drama, Thriller]
# 15        16         [Adventure, Fantasy, Action]
# 57        58             [Action, ScienceFiction]
# 99       100   [Action, Thriller, ScienceFiction]
# 151      152  [Adventure, Action, ScienceFiction]
# 221      222                  [Adventure, Action]
# 246      247                     [Drama, Romance]
# 248      249             [Crime, Drama, Thriller]
# 289      290                              [Drama]
# 320      321                  [Adventure, Action]
#
#                                               keywords  \
# 11   [dccomics, crimefighter, terrorist, secretiden...
# 15   [elves, dwarves, orcs, middle-earth(tolkien), ...
# 57   [artificialintelligence, telepathy, intelligen...
# 99   [suicide, assassin, drugaddiction, future, tim...
# 151  [senate, investigation, army, deathstar, jedi,...
# 221  [savingtheworld, venice, holygrail, library, r...
# 246  [individual, schizophrenia, massachusetts, lov...
# 248  [basedonnovel, sniper, investigation, police, ...
# 289  [individual, philosophy, poetry, shakespeare, ...
# 320  [savingtheworld, riddle, whip, treasure, mexic...
#
#                                                  title  \
# 11                               The Dark Knight Rises
# 15   The Lord of the Rings: The Fellowship of the Ring
# 57                                                Lucy
# 99                                              Looper
# 151       Star Wars: Episode II - Attack of the Clones
# 221                 Indiana Jones and the Last Crusade
# 246                                   A Beautiful Mind
# 248                                       Jack Reacher
# 289                                 Dead Poets Society
# 320  Indiana Jones and the Kingdom of the Crystal S...
#
#                                               overview  \
# 11   [Following, the, death, of, District, Attorney...
# 15   [Young, hobbit, Frodo, Baggins,, after, inheri...
# 57   [A, woman,, accidentally, caught, in, a, dark,...
# 99   [In, the, futuristic, action, thriller, Looper...
# 151  [Ten, years, after, the, invasion, of, Naboo,,...
# 221  [When, Dr., Henry, Jones, Sr., suddenly, goes,...
# 246  [At, Princeton, University,, John, Nash, strug...
# 248  [In, an, innocent, heartland, city,, five, are...
# 289  [At, an, elite,, old-fashioned, boarding, scho...
# 320  [Set, during, the, Cold, War,, the, Soviets, –...
#
#                                                   cast  \
# 11           [ChristianBale, MichaelCaine, GaryOldman]
# 15            [ElijahWood, IanMcKellen, CateBlanchett]
# 57     [ScarlettJohansson, MorganFreeman, ChoiMin-sik]
# 99      [JosephGordon-Levitt, BruceWillis, EmilyBlunt]
# 151  [EwanMcGregor, NataliePortman, HaydenChristensen]
# 221        [HarrisonFord, SeanConnery, DenholmElliott]
# 246         [RussellCrowe, EdHarris, JenniferConnelly]
# 248          [TomCruise, RosamundPike, RichardJenkins]
# 289     [RobinWilliams, EthanHawke, RobertSeanLeonard]
# 320         [HarrisonFord, CateBlanchett, ShiaLaBeouf]
#
#                        crew  tmdbId  \
# 11       [ChristopherNolan]   49026
# 15           [PeterJackson]     120
# 57              [LucBesson]  240832
# 99            [RianJohnson]   59967
# 151           [GeorgeLucas]    1894
# 221       [StevenSpielberg]      89
# 246             [RonHoward]     453
# 248  [ChristopherMcQuarrie]   75780
# 289             [PeterWeir]     207
# 320       [StevenSpielberg]     217
#
#                                                   tags
# 11   [Following, the, death, of, District, Attorney...
# 15   [Young, hobbit, Frodo, Baggins,, after, inheri...
# 57   [A, woman,, accidentally, caught, in, a, dark,...
# 99   [In, the, futuristic, action, thriller, Looper...
# 151  [Ten, years, after, the, invasion, of, Naboo,,...
# 221  [When, Dr., Henry, Jones, Sr., suddenly, goes,...
# 246  [At, Princeton, University,, John, Nash, strug...
# 248  [In, an, innocent, heartland, city,, five, are...
# 289  [At, an, elite,, old-fashioned, boarding, scho...
# 320  [Set, during, the, Cold, War,, the, Soviets, –...

# %%
from joblib import dump
dump(movie_fmf_mat, 'model/funk_model.joblib')
# Out:
# ['model/funk_model.joblib']

# %%
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# import gc

# from collections import defaultdict

# # synthesize data
# NUM_USERS = 101
# NUM_ITEMS = 1501
# user_id = np.arange(start = 0, stop = NUM_USERS)
# item_id = np.arange(start = 0, stop = NUM_ITEMS)
# np.random.seed(42)

# user_item_dict = defaultdict(list)

# for id in user_id:
    
#     # random the number of item generation
#     # for each user, random 3 to 5 items to be rated.
#     num_rand_item = np.random.randint(low = 3, high = 8)

#     # random from the item_id
#     rand_items = np.random.choice(item_id, size = num_rand_item, replace = False)

#     # random rating for each itme_id
#     rand_rating = np.random.randint(low = 1, high = 5, size = num_rand_item)

#     # collect the user-item paris.
#     for uid, iid,rating in zip([id] * num_rand_item, rand_items, rand_rating):
#         user_item_dict['userid'].append(uid)
#         user_item_dict['movieId'].append(iid)
#         user_item_dict['rating'].append(rating)

# # prepare dataframe
# ratings = pd.DataFrame(user_item_dict)
# print("Rating Dataframe")
# ratings[['userid','movieId']] = ratings[['userid','movieId']].astype(str)
# display(ratings.head())

# %%
# ratings.to_csv('ratings_new.csv',index=False)
